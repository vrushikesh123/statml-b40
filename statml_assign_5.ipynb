# %% [markdown]
# <a href="https://colab.research.google.com/github/vrushikesh123/statml-b40/blob/main/statml_assign_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# NAME:k.vrushikesh
# HT.NO:2303A52218
# BATCH:40

# %% [markdown]
# question-1

# %%
import pandas as pd
file_path = 'salary.xls'
data = pd.read_excel(file_path)
print(data.head())
X = data.iloc[:,:-1]
Y = data.iloc[:,-1]
print("Features:\n",X.head())
print("Target:\n",Y.head())
import matplotlib.pyplot as plt
for column in X.columns:
  plt.figure(figsize=(8,6))
  plt.scatter(X[column],y,alpha=0.5)
  plt.title(f"{column} vs Target")
  plt.xlabel(column)
  plt.ylabel("Target")
  plt.show()
  from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_normalised = scaler.fit_transform(X)
y_normalised = scaler.fit_transform(y.values.reshape(-1,1))
X_normalised = pd.DataFrame(X_normalised,columns=X.columns)
y_normalised = pd.Series(y_normalised.flatten(),name="Target")
print("Normalised Features:\n",X_normalised.head())
# Out:
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205
# 2              1.5   37731
# 3              2.0   43525
# 4              2.2   39891
# Features:
#     YearsExperience
# 0              1.1
# 1              1.3
# 2              1.5
# 3              2.0
# 4              2.2
# Target:
#  0    39343
# 1    46205
# 2    37731
# 3    43525
# 4    39891
# Name: Salary, dtype: int64
# Normalised Features:
#     YearsExperience
# 0         0.000000
# 1         0.021277
# 2         0.042553
# 3         0.095745
# 4         0.117021

# %%
import pandas as pd
file_path = 'diabetes.xls'
data = pd.read_excel(file_path)
print(data.head())
X = data.iloc[:,:-1]
Y = data.iloc[:,-1]
print("Features:\n",X.head())
print("Target:\n",Y.head())
import matplotlib.pyplot as plt
for column in X.columns:
  plt.figure(figsize=(8,6))
  #plt.scatter(X[column],y,alpha=0.5)
  plt.title(f"{column} vs Target")
  plt.xlabel(column)
  plt.ylabel("Target")
  plt.show()
# Out:
#    Age Gender Polyuria Polydipsia sudden weight loss weakness Polyphagia  \
# 0   40   Male       No        Yes                 No      Yes         No
# 1   58   Male       No         No                 No      Yes         No
# 2   41   Male      Yes         No                 No      Yes        Yes
# 3   45   Male       No         No                Yes      Yes        Yes
# 4   60   Male      Yes        Yes                Yes      Yes        Yes
#
#   Genital thrush visual blurring Itching Irritability delayed healing  \
# 0             No              No     Yes           No             Yes
# 1             No             Yes      No           No              No
# 2             No              No     Yes           No             Yes
# 3            Yes              No     Yes           No             Yes
# 4             No             Yes     Yes          Yes             Yes
#
#   partial paresis muscle stiffness Alopecia Obesity     class
# ...
